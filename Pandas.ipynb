# %%
import pandas as pd

# %%
raw_data = pd.read_csv("data.csv")

# %%
raw_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
raw_data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
#Boolean masking

raw_data['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
# 5      M
# 6      M
# 7      M
# 8      M
# 9      M
# 10     M
# 11     M
# 12     M
# 13     M
# 14     M
# 15     M
# 16     M
# 17     M
# 18     M
# 19     B
# 20     B
# 21     B
# 22     M
# 23     M
# 24     M
# 25     M
# 26     M
# 27     M
# 28     M
# 29     M
#       ..
# 539    B
# 540    B
# 541    B
# 542    B
# 543    B
# 544    B
# 545    B
# 546    B
# 547    B
# 548    B
# 549    B
# 550    B
# 551    B
# 552    B
# 553    B
# 554    B
# 555    B
# 556    B
# 557    B
# 558    B
# 559    B
# 560    B
# 561    B
# 562    M
# 563    M
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
raw_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
raw_data[raw_data.columns[1]] == 'M'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19     False
# 20     False
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 539    False
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# 550    False
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# 562     True
# 563     True
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
raw_data.columns[1]
# Out:
# 'diagnosis'

# %%
boolean_mask = (raw_data[raw_data.columns[2]] >= 15.67) & (raw_data[raw_data.columns[1]] == 'M')

# %%
raw_data[boolean_mask]
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0       842302         M        17.99         10.38           122.8
# 1       842517         M        20.57         17.77           132.9
# 2     84300903         M        19.69         21.25           130.0
# 4     84358402         M        20.29         14.34           135.1
# 6       844359         M        18.25         19.98           119.6
# 10      845636         M        16.02         23.24           102.7
# 11    84610002         M        15.78         17.89           103.6
# 12      846226         M        19.17         24.80           132.4
# 13      846381         M        15.85         23.95           103.7
# 17    84862001         M        16.13         20.68           108.1
# 18      849014         M        19.81         22.15           130.0
# 23      851509         M        21.16         23.04           137.2
# 24      852552         M        16.65         21.38           110.0
# ...

# %%
sliced_off = raw_data.iloc[9:19,3:6]

# %%
raw_data.loc[:,'id':'texture_mean']
# Out:
#            id diagnosis  radius_mean  texture_mean
# 0      842302         M       17.990         10.38
# 1      842517         M       20.570         17.77
# 2    84300903         M       19.690         21.25
# 3    84348301         M       11.420         20.38
# 4    84358402         M       20.290         14.34
# 5      843786         M       12.450         15.70
# 6      844359         M       18.250         19.98
# 7    84458202         M       13.710         20.83
# 8      844981         M       13.000         21.82
# 9    84501001         M       12.460         24.04
# 10     845636         M       16.020         23.24
# 11   84610002         M       15.780         17.89
# 12     846226         M       19.170         24.80
# 13     846381         M       15.850         23.95
# 14   84667401         M       13.730         22.61
# 15   84799002         M       14.540         27.54
# 16     848406         M       14.680         20.13
# ...

# %%
d = {'odd': [25,11,21,15], 'prime': [17,19,7,31]}

# %%
d['odd']
# Out:
# [25, 11, 21, 15]

# %%
d['prime']
# Out:
# [17, 19, 7, 31]

# %%
dict_data = pd.DataFrame(data=d)

# %%
dict_data
# Out:
#    odd  prime
# 0   25     17
# 1   11     19
# 2   21      7
# 3   15     31

# %%
odd
# Out:
# [25, 11, 21, 15]

# %%
prime
# Out:
# [17, 19, 7, 31]

# %%
main_list = [odd, prime]

# %%
main_list
# Out:
# [[25, 11, 21, 15], [17, 19, 7, 31]]

# %%
list_data = pd.DataFrame(data = main_list, columns = ['c1', 'c2', 'c3', 'c4'])

# %%
list_data
# Out:
#    c1  c2  c3  c4
# 0  25  11  21  15
# 1  17  19   7  31

# %%
columns_list = raw_data.columns

columns_list = list(columns_list)

# %%
raw_data.iloc[:,columns_list.index('id'): columns_list.index('texture_mean')]
# Out:
#            id diagnosis  radius_mean
# 0      842302         M       17.990
# 1      842517         M       20.570
# 2    84300903         M       19.690
# 3    84348301         M       11.420
# 4    84358402         M       20.290
# 5      843786         M       12.450
# 6      844359         M       18.250
# 7    84458202         M       13.710
# 8      844981         M       13.000
# 9    84501001         M       12.460
# 10     845636         M       16.020
# 11   84610002         M       15.780
# 12     846226         M       19.170
# 13     846381         M       15.850
# 14   84667401         M       13.730
# 15   84799002         M       14.540
# 16     848406         M       14.680
# 17   84862001         M       16.130
# 18     849014         M       19.810
# 19    8510426         B       13.540
# 20    8510653         B       13.080
# 21    8510824         B        9.504
# 22    8511133         M       15.340
# 23     851509         M       21.160
# ...
